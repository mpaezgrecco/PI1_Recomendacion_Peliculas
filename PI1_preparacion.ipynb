# %% [markdown]
# Preparacion de los datos

# %%
# importar los modulos 
import pandas as pd
import ast
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# lectura y almacenamiento de datos 
data = pd.read_csv("movies_dataset.csv")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_46236\1272152841.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("movies_dataset.csv")

# %%
#Visualización de los Primeros Registros
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Informacion de los datos 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# Algunos campos, como belongs_to_collection, production_companies y otros (ver diccionario de datos) están anidados, esto es o bien tienen un diccionario o una lista como valores en cada fila, ¡deberán desanidarlos para poder y unirlos al dataset de nuevo hacer alguna de las consultas de la API! O bien buscar la manera de acceder a esos datos sin desanidarlos.

# %%
# función para convertir un diccionario a string y extraer el valor de "name"
def parse_and_extract_name(record):
    if record is None:
        return None
    if isinstance(record, dict):
        return record.get('name')
    # Si record es una cadena que parece un diccionario, evalúa y extrae "name"
    if isinstance(record, str):
        try:
            record_dict = eval(record)
            if isinstance(record_dict, dict):
                return record_dict.get('name')
        except:
            return None
    return None

# Aplicar la función a la columna "belongs_to_collection" y crear la nueva columna "name_to_collection"
data['name_to_collection'] = data['belongs_to_collection'].apply(parse_and_extract_name)

# %%
# ver la nueva columna "name_to_collection"
data.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#        revenue runtime                          spoken_languages    status  \
# 0  373554033.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#   tagline      title  video vote_average vote_count    name_to_collection
# 0     NaN  Toy Story  False          7.7     5415.0  Toy Story Collection
#
# [1 rows x 25 columns]

# %%
# Función para extraer los nombres de los géneros
def extract_name(genres):
    if isinstance(genres, str):
        try:
            genres = ast.literal_eval(genres)  # Convertir la cadena en una lista de diccionarios
        except (ValueError, SyntaxError):
            return None
    if isinstance(genres, list):
        return [item.get('name') for item in genres if isinstance(item, dict)]
    return None

# Aplicar la función directamente a la columna 'genres'
data['name_genres'] = data['genres'].apply(extract_name)

# %%
# Para ver la nueva columna "name_genres"
data.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# ...

# %%
def desanidar_name(columna, lugar_data):
    # lugar_data indica la posicion del disccionario donde esta ubicado name
    global data

    # Convertir strings JSON en listas de diccionarios
    data[columna] = data[columna].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

    # Extraer los nombres en la posición especificada y almacenarlos en una nueva columna
    data[f'name_{columna}'] = data[columna].apply(
        lambda x: [dic.get('name') for dic in x] if isinstance(x, list) else []
    ).apply(lambda x: x[lugar_data] if len(x) > lugar_data else None)

# %%
# Aplicar la función a la columna 'production_companies'
desanidar_name("production_companies", 0)

# %%
#para observar los datos 
data.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#                            spoken_languages    status tagline      title  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released     NaN  Toy Story
#
#    video  vote_average  vote_count    name_to_collection  \
# 0  False           7.7      5415.0  Toy Story Collection
#
#                    name_genres name_production_companies
# 0  [Animation, Comedy, Family]   Pixar Animation Studios
#
# [1 rows x 27 columns]

# %%
#desanidamos el lenguaje 
desanidar_name("spoken_languages", 0)

# %%
#visualizamos los datos 
data.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#      status tagline      title  video vote_average  vote_count  \
# 0  Released     NaN  Toy Story  False          7.7      5415.0
#
#      name_to_collection                  name_genres  \
# 0  Toy Story Collection  [Animation, Comedy, Family]
#
#   name_production_companies name_spoken_languages
# 0   Pixar Animation Studios               English
#
# [1 rows x 28 columns]

# %%
#utilizando la funcion creada anteriormente vamos a desanidar el pais
desanidar_name("production_countries", 0)

# %%
# ver la nueva columna 
data.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   tagline      title  video vote_average vote_count    name_to_collection  \
# 0     NaN  Toy Story  False          7.7     5415.0  Toy Story Collection
#
#                    name_genres name_production_companies  \
# 0  [Animation, Comedy, Family]   Pixar Animation Studios
#
#   name_spoken_languages name_production_countries
# 0               English  United States of America
#
# [1 rows x 29 columns]

# %% [markdown]
# Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0.

# %%
# Rellenar valores nulos de las columnas 'revenue' y 'budget' con 0
data['revenue'] = data['revenue'].fillna(0)
data['budget'] = data['budget'].fillna(0)

# %% [markdown]
# Los valores nulos del campo release date deben eliminarse.

# %%
data = data.dropna(subset=['release_date'])

# %% [markdown]
# De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year donde extraerán el año de la fecha de estreno.

# %%
# Convertir la columna 'release_date' al formato de fecha AAAA-mm-dd
data['release_date'] = pd.to_datetime(data['release_date'], errors='coerce', format='%Y-%m-%d')

# %%
# Eliminar filas con fechas no válidas (que no pudieron convertirse)
data = data.dropna(subset=['release_date'])

# %%
# Extraer el año de la fecha de estreno y crear la nueva columna 'release_year'
data['release_year'] = data['release_date'].dt.year

# %%
data.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#        title  video vote_average vote_count    name_to_collection  \
# 0  Toy Story  False          7.7     5415.0  Toy Story Collection
#
#                    name_genres  name_production_companies  \
# 0  [Animation, Comedy, Family]    Pixar Animation Studios
#
#   name_spoken_languages name_production_countries release_year
# 0               English  United States of America         1995
#
# [1 rows x 30 columns]

# %% [markdown]
# Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget, dividiendo estas dos últimas revenue / budget, cuando no hay datos disponibles para calcularlo, deberá tomar el valor 0.

# %%
# Convertir 'budget' a tipo float
data['budget'] = data['budget'].astype(float)

# %%
# Crear la columna 'return' con el cálculo de revenue / budget
data['return'] = np.where((data['budget'] == 0) | (data['revenue'] == 0) | (data['budget'].isna()) | (data['revenue'].isna()), 
                          0, 
                          data['revenue'] / data['budget'])

# %%
data.head()
# Out:
#    adult                              belongs_to_collection      budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1  False                                                NaN  65000000.0
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3  False                                                NaN  16000000.0
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# Eliminar las columnas que no serán utilizadas, video,imdb_id,adult,original_title,poster_path y homepage.

# %%
# Eliminar las columnas no utilizadas
data = data.drop(columns=['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   belongs_to_collection      4488 non-null   object
#  1   budget                     45376 non-null  float64
#  2   genres                     45376 non-null  object
#  3   id                         45376 non-null  object
#  4   original_language          45365 non-null  object
#  5   overview                   44435 non-null  object
#  6   popularity                 45376 non-null  object
#  7   production_companies       45376 non-null  object
#  8   production_countries       45376 non-null  object
#  9   release_date               45376 non-null  datetime64[ns]
#  10  revenue                    45376 non-null  float64
#  11  runtime                    45130 non-null  float64
#  12  spoken_languages           45376 non-null  object
# ...

# %% [markdown]
# Continuemos con el archivo credits.csv

# %%
data_credits = pd.read_csv("credits.csv")

# %%
data_credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
data_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
# funcion para pasar de diccionario a string

def dict_to_string(value):
    if pd.isna(value):
        return None
    else:
        return ast.literal_eval(value)

# %%
# Aplicamos la funcion a la columna Cast
data_credits["cast"] = data_credits["cast"].apply(dict_to_string)

# %%
# Función para extraer names 
def values(registros):
    names = [registro['name'] for registro in registros]
    return pd.Series({'names': names})

# Aplicar la función a la columna 'registros' y expandir los resultados en nuevas columnas
data_credits['names_actors'] = data_credits['cast'].apply(values)

# %%
data_credits.head(1)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
#
#                                                 crew   id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...  862
#
#                                         names_actors
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...

# %%
# Aplicamos la funcion a la columna Crew
data_credits["crew"] = data_credits["crew"].apply(dict_to_string)

# %%
# Función para extraer el valor de "name" de los registros 
def extraer_nombre_director(registros):
    if registros is None:
        return None
    for registro in registros:
        if registro['job'] == 'Director':
            return registro['name']
    return None

# Aplicar la función y crear una nueva columna llamada "name_director"
data_credits['name_director'] = data_credits['crew'].apply(lambda x: extraer_nombre_director(x))

# %%
data_credits.head(1)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
#
#                                                 crew   id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...  862
#
#                                         names_actors  name_director
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...  John Lasseter

# %%
# A continuacion vamos a concatenar los datos continuaremos utilizando 
datos_seleccionadas = ["id", "names_actors", "name_director"]

# DataFrame nuevo con las columnas anteriores
creditsconcate= data_credits.loc[:, datos_seleccionadas]

# %%
creditsconcate.head(1)
# Out:
#     id                                       names_actors  name_director
# 0  862  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...  John Lasseter

# %% [markdown]
# Convertir la columna 'Columna' de tipo str a int64

# %%
#1. revision de los datos
# Verificar los primeros registros de la columna 'id'
print(data['id'].head())

# Comprobar los valores únicos en la columna 'id'
print(data['id'].unique())
# Out:
# 0      862
# 1     8844
# 2    15602
# 3    31357
# 4    11862
# Name: id, dtype: object
# ['862' '8844' '15602' ... '67758' '227506' '461257']

# %%
# Convertir la columna a tipo int64
data['id'] = data['id'].astype('int64')

# %%
# combinar dos DataFrames (data y credits_concatenar) en función de la columna 'id'
datafinal = pd.merge(data, creditsconcate, on='id', how='inner')

# %%
# Veamos los nuevos datos
datafinal.head(1)
# Out:
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
#
#                                               genres   id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
#
#                              production_companies  \
# 0  [{'name': 'Pixar Animation Studios', 'id': 3}]
#
#                                 production_countries release_date  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30  ...
#
#    vote_count    name_to_collection                  name_genres  \
# 0      5415.0  Toy Story Collection  [Animation, Comedy, Family]
#
#   name_production_companies name_spoken_languages name_production_countries  \
# 0   Pixar Animation Studios               English  United States of America
#
# ...

# %%
#Eliminemos las columnas de los registros que desanidamos
datafinal = datafinal.drop(["belongs_to_collection", "genres", "production_companies", "production_countries", "spoken_languages"], axis=1)
datafinal.head(1)
# Out:
#        budget   id original_language  \
# 0  30000000.0  862                en
#
#                                             overview popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
#
#        revenue  runtime    status tagline  ... vote_count  \
# 0  373554033.0     81.0  Released     NaN  ...     5415.0
#
#      name_to_collection                  name_genres  \
# 0  Toy Story Collection  [Animation, Comedy, Family]
#
#   name_production_companies name_spoken_languages name_production_countries  \
# 0   Pixar Animation Studios               English  United States of America
#
#   release_year     return                                       names_actors  \
# 0         1995  12.451801  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
#
#    name_director
# 0  John Lasseter
#
# [1 rows x 22 columns]

# %%
datafinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45451 entries, 0 to 45450
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   budget                     45451 non-null  float64
#  1   id                         45451 non-null  int64
#  2   original_language          45440 non-null  object
#  3   overview                   44510 non-null  object
#  4   popularity                 45451 non-null  object
#  5   release_date               45451 non-null  datetime64[ns]
#  6   revenue                    45451 non-null  float64
#  7   runtime                    45205 non-null  float64
#  8   status                     45371 non-null  object
#  9   tagline                    20425 non-null  object
#  10  title                      45451 non-null  object
#  11  vote_average               45451 non-null  float64
#  12  vote_count                 45451 non-null  float64
# ...

# %% [markdown]
# Para facilitar su manejo y procesamiento de los datos vamos a dividir el DataFrame en partes mas pequeñas

# %%
num_filas = datafinal.shape[0]
print(f"El DataFrame tiene {num_filas} filas.")
# Out:
# El DataFrame tiene 45451 filas.

# %%
#divideros el dataframe en 2 partes iguales con 22688 filas cada uno 
parte1 = datafinal[:22688]  # Primeras filas
parte2 = datafinal[22688:]  # Primeras filas

# %%
# Guardar las partes en archivos CSV separados
parte1.to_csv('movies_datasets_parte1.csv', index=False)
parte2.to_csv('movies_datasets_parte2.csv', index=False)

# %%
# Preparamos los datos para el modelo de machine learning

# %%
datafinal.columns
# Out:
# Index(['budget', 'id', 'original_language', 'overview', 'popularity',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'vote_average', 'vote_count', 'name_to_collection', 'name_genres',
#        'name_production_companies', 'name_spoken_languages',
#        'name_production_countries', 'release_year', 'return', 'names_actors',
#        'name_director'],
#       dtype='object')

# %%
datafinal.columns = datafinal.columns.str.strip()

# %%
dataset_ML = datafinal[["budget", "original_language", "popularity", "release_date", "revenue", "title", "vote_average", "vote_count", "name_genres", "release_year", "return", "names_actors", "name_director"]]

# %%
# Filtrar las peliculas que tengan vote_average mayor a 0 para eliminar peliculas que no se tendran en cuneta
dataset_ML= dataset_ML[dataset_ML['vote_average'] > 0]

# %%
# Creamos el archivo csv
dataset_ML.to_csv("dataset_ML.csv", index=False)
